# %% [markdown]
# <a href="https://colab.research.google.com/github/IU2441230156collegework/PSC_College_work/blob/main/Copy_of_IU2441230156_basic_practicals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)write a python program to add three numberes.
# 2)Find out sqrt of a number
# 3)Calculate the area of the triagnle
# 4)swap two vairables with using a temporary vairable and without using a    temperory vairable

# %%
a = int(input("Enter First number :"))
b = int(input("Enter Second number :"))
c = int(input("Enter Third number :"))


sum = a + b + c
print ("sum is :",sum)
# Out:
# Enter First number :1
# Enter Second number :2
# Enter Third number :3
# sum is : 6

# %% [markdown]
# 2)Find out sqrt of a number

# %%
import math

number = 25
result = math.sqrt(number)
print(result)
# Out:
# 5.0

# %% [markdown]
#  3)Calculate the area of the triagnle

# %%
b = int(input("Enter the breadth :"))
h= int(input("Enter the height :"))
area = 1/2*b*h
print(area)
# Out:
# Enter the breadth :10
# Enter the height :5
# 25.0

# %% [markdown]
#  4)swap two vairables with using a temporary vairable and without using a temperory vairable

# %%
a= 10
b = 20
print(a,b)
temp = a
a= b
b= temp
print(a,b)
# Out:
# 10 20
# 20 10

# %%
a = 10
b = 20
print(a,b)
a,b = b,a
print(a,b)
# Out:
# 10 20
# 20 10

# %% [markdown]
# 5) display the multiplication table
# 1) with loop
# 2)without loop

# %%
#without loop
n = int(input())
print(n,"X 1 = ",n*1)
print(n,"X 2 = ",n*2)
print(n,"X 3 = ",n*3)
print(n,"X 4 = ",n*4)
print(n,"X 5 = ",n*5)
print(n,"X 6 = ",n*6)
print(n,"X 7 = ",n*7)
print(n,"X 8 = ",n*8)
print(n,"X 9 = ",n*9)
print(n,"X 10 =",n*10)
# Out:
# 12
# 12 X 1 =  12
# 12 X 2 =  24
# 12 X 3 =  36
# 12 X 4 =  48
# 12 X 5 =  60
# 12 X 6 =  72
# 12 X 7 =  84
# 12 X 8 =  96
# 12 X 9 =  108
# 12 X 10 = 120

# %%
#WITH LOOP
n = int(input())
for i in range(1,11):
  print(n,"X",i,"=",n*i)
# Out:
# 10
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100
